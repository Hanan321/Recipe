# %% [markdown]
# <a href="https://colab.research.google.com/github/Hanan321/Recipe/blob/main/Arabic_AI_Chef.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Arabic AI Chef")
print("Welcome! Let's explore Arabic cuisine with AI ideas.")
# Out:
# Arabic AI Chef
# Welcome! Let's explore Arabic cuisine with AI ideas.

# %%
print("Choose a city:")
print("1. Riyadh")
print("2. Cairo")
print("3. Amman")
print("4. Rabat")
print("5. Tripoli")
print("6. Khartoum")
# Out:
# Choose a city:
# 1. Riyadh
# 2. Cairo
# 3. Amman
# 4. Rabat
# 5. Tripoli
# 6. Khartoum

# %%
choice = input("Enter the number of your choice: ").strip()
# Out:
# Enter the number of your choice: 1

# %%
city_options = {
    "1": "Riyadh",
    "2": "Cairo",
    "3": "Amman",
    "4": "Rabat",
    "5": "Tripoli",
    "6": "Khartoum"
}

city = city_options.get(choice)

if city:
    print("You selected:", city)
else:
    print("Invalid choice")
# Out:
# You selected: Riyadh

# %%
import os
from getpass import getpass

os.environ["OPENAI_API_KEY"] = getpass("Paste your API key: ")
# Out:
# Paste your API key: ··········

# %%
from openai import OpenAI

client = OpenAI()

if city:
    dish = city_dishes[city]

    prompt = f"""
    You are a culinary AI assistant.

    City: {city}
    Dish: {dish}

    Write clearly:

    Ingredients:
    Recipe Steps:
    Estimated Cost:
    Plating Description:
    Image Prompt:
    """

    response = client.responses.create(
        model="gpt-5.4",
        input=prompt
    )

    print(response.output_text)
# Out:
# **Ingredients:**
# - 1 whole chicken, cut into 4–6 pieces
# - 2 cups basmati rice
# - 2 large onions, finely chopped
# - 3 tomatoes, chopped
# - 3 tbsp tomato paste
# - 4 garlic cloves, minced
# - 2 carrots, grated
# - 3 tbsp vegetable oil or ghee
# - 4 cups chicken stock or water
# - 2 bay leaves
# - 4 cloves
# - 4 cardamom pods
# - 1 cinnamon stick
# - 1 tsp black pepper
# - 1 tsp ground cumin
# - 1 tsp ground coriander
# - 1 tsp turmeric
# - 1 tsp paprika
# - 1 tsp kabsa spice mix
# - Salt to taste
# - ¼ cup raisins
# - ¼ cup toasted almonds or pine nuts
#
# **Recipe Steps:**
# 1. Wash the rice and soak it for 20–30 minutes, then drain.
# 2. Heat oil or ghee in a large pot over medium heat.
# 3. Add chopped onions and cook until golden.
# 4. Add garlic, tomatoes, tomato paste, and grated carrots. Cook for 5 minutes.
# 5. Add bay leaves, cloves, cardamom, cinnamon, black pepper, cumin, coriander, turmeric, paprika, kabsa spice, and salt.
# 6. Add chicken pieces and stir well until coated with the spice mixture.
# 7. Pour in chicken stock or water. Cover and simmer for 30–40 minutes until the chicken is cooked.
# 8. Remove the chicken pieces and set aside.
# 9. Add the soaked rice to the same pot with the broth. Adjust salt if needed.
# 10. Cook the rice on medium heat until most of the liquid is absorbed.
# 11. Lower the heat, cover, and steam for 20 minutes until the rice is tender.
# 12. Meanwhile, grill or broil the chicken for a few minutes to give it a golden color.
# 13. Serve the rice on a large platter, place chicken on top, and garnish with raisins and toasted almonds or pine nuts.
#
# **Estimated Cost:**
# - Approximate total cost in Riyadh: **35–55 SAR**
# - Cost may vary depending on chicken quality, nuts, and spice brands.
#
# **Plating Description:**
# Serve the Chicken Kabsa on a large round serving platter. Spread the fragrant spiced rice evenly across the base. Arrange the golden chicken pieces neatly on top. Sprinkle raisins and toasted almonds or pine nuts over the rice and chicken. For a traditional Riyadh-style presentation, serve with a side of tomato salsa (dakkous) and lemon wedges.
#
# **Image Prompt:**
# A traditional Saudi Chicken Kabsa served on a large round platter, fragrant long-grain basmati rice with warm spices, golden roasted chicken pieces arranged on top, garnished with raisins and toasted almonds, rustic Middle Eastern table setting, side of dakkous and lemon wedges, soft natural lighting, appetizing and authentic presentation, Riyadh style.
